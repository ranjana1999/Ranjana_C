# %%
from keras.datasets import mnist
data = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
(X_train, Y_train), (X_test, Y_test) = data

# %%
X_train = X_train.reshape((X_train.shape[0], 28*28)).astype('float32')
X_test = X_test.reshape((X_test.shape[0], 28*28)).astype('float32')

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
from keras.utils import np_utils

print(Y_test.shape)

Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)

num_classes = Y_test.shape[1]
print(Y_test.shape)
# Out:
# (10000,)
# (10000, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(32, input_dim = 28*28, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.7852 - accuracy: 0.7702
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2158 - accuracy: 0.9382
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1614 - accuracy: 0.9534
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1309 - accuracy: 0.9601
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1078 - accuracy: 0.9684
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0949 - accuracy: 0.9719
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0849 - accuracy: 0.9746
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0736 - accuracy: 0.9775
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0693 - accuracy: 0.9792
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0636 - accuracy: 0.9804

# %%
scores = model.evaluate(X_test, Y_test)
print(scores)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0976 - accuracy: 0.9692
# [0.09761187434196472, 0.9692000150680542]
